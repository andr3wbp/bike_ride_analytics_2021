# %% [markdown]
# ## Data Analytics and Visualization of a longer (200 km +) bike ride
# #### The session was measured with a Polar Vantage V watch, raw data is generated by polar
# #### Input (2 files):
# - training (csv) for speed, elevation, etc
# - gps coordinates (gpx)
#
# The training csv file needs to be cleaned (split up into time series and reference data pars)

# %%
import pandas as pd
import os
import gpxpy
import matplotlib.pyplot as plt
import datetime
from pprint import pprint

# %%
folder = ".\data\\"
file_list = os.listdir(folder)

for index, file in enumerate(file_list):
    file = (index, folder + file)
    file_list[index] = file
    
filelist_df = pd.DataFrame(file_list, columns=['index', 'file_path']).set_index('index')
filelist_df['extension'] = filelist_df.file_path.str.split('.').str[-1].str.lower()

labels = {'csv': 'training', 'gpx': 'gps'}
filelist_df['label'] = filelist_df.extension.map(labels)
filelist_df.set_index('label', inplace=True)
display(filelist_df)
# Out:
#                                             file_path extension
# label
# training  .\data\Andrew_Szabo_2021-06-25_04-37-58.CSV       csv
# gps       .\data\Andrew_Szabo_2021-06-25_04-37-58.GPX       gpx

# %% [markdown]
# ### Create:
# - training_raw
# - coordinates

# %%
training_raw = pd.read_csv(filelist_df.loc['training', 'file_path'], low_memory=False)

# gpx file step 1 (gpxpy.parse the file)
with open(filelist_df.loc['gps', 'file_path'], 'r') as f:
    gpx_file = gpxpy.parse(f)
# gpx file step 2 (segment)   
segment = gpx_file.tracks[0].segments[0]

# # gpx file step 3 (loop through segment.points)
coordinates = pd.DataFrame([{
    'time': p.time,
    'latitude': p.latitude,
    'longitude': p.longitude,
    'elevation': p.elevation} for p in segment.points
])
coordinates.set_index('time', inplace=True)

# %% [markdown]
# ### Inspect:
# - training_raw
# - coordinates

# %%
df_names = ["training_raw", "coordinates"]
df_list = [training_raw, coordinates]
df_zipped = zip(df_names, df_list)

for name, df in df_zipped:
    print("df name: " + name)
    display(df.head(8))
    
#clean df variable from memory
df = '_'
# Out:
# df name: training_raw
#            Name     Sport        Date    Start time       Duration  \
# 0  Andrew Szabo   CYCLING  2021.06.25   04:37:58 AM       09:33:46
# 1   Sample rate      Time    HR (bpm)  Speed (km/h)  Pace (min/km)
# 2             1  00:00:00          87           0.0          00:00
# 3           NaN  00:00:01          87           0.0          00:00
# 4           NaN  00:00:02          87           0.0          00:00
# 5           NaN  00:00:03          87           0.0          00:00
# 6           NaN  00:00:04          87           3.7          16:10
# 7           NaN  00:00:05          86           5.6          10:42
#
#   Total distance (km) Average heart rate (bpm) Average speed (km/h)  \
# 0              207.37                      114                 21.7
# 1             Cadence             Altitude (m)    Stride length (m)
# 2                 NaN                      116                  NaN
# ...

# %% [markdown]
# ### Conclusion:
#
# #### training file (training_raw) should be split into 2 distinct dataframes:
# - Header and first row are reference data (static/calculated based on the time series (ts))
# - Not nan part of the 2nd row is the new header for the ts data starting from the 3rd row
# #### gpx file shows time zone incorrectly:
# - we started the recording at 4:37 am and not 2:47
# - there is no need for [ms] data. granulatiry should be [s]
# - there may be room for reducing file size (resampling -> taking every nth second only for plotting)

# %% [markdown]
# #### Create:
# - training_meta

# %%
training_meta = pd.DataFrame(training_raw.iloc[0,:])
display(training_meta)
# Out:
#                                                                                0
# Name                                                                Andrew Szabo
# Sport                                                                    CYCLING
# Date                                                                  2021.06.25
# Start time                                                           04:37:58 AM
# Duration                                                                09:33:46
# Total distance (km)                                                       207.37
# Average heart rate (bpm)                                                     114
# Average speed (km/h)                                                        21.7
# Max speed (km/h)                                                            52.0
# Average pace (min/km)                                                      02:46
# Max pace (min/km)                                                          01:09
# ...

# %% [markdown]
# #### Create:
# - training_ts
#
# (ts=time series)

# %%
# 2nd row of the training_raw should be the new header, nulls are dropped
new_ts_cols = [x for x in training_raw.iloc[1,:] if pd.isnull(x) == False]

# slicing the ts part of the raw dataset
training_ts = training_raw.iloc[2:, :len(new_ts_cols)]

# the columns are incorrect by default due to data quality. They need to be replaced
incorrect_cols = training_ts.columns
col_replace_rule = {bad: good for bad, good in zip(incorrect_cols, new_ts_cols)}

print("key: old col name, value: new col name")
print()
pprint(col_replace_rule)

# fix erroneous colnames
training_ts.rename(columns=col_replace_rule, inplace=True)
training_ts.head()
# Out:
# key: old col name, value: new col name
#
# {'Average heart rate (bpm)': 'Altitude (m)',
#  'Average pace (min/km)': 'Temperatures (C)',
#  'Average speed (km/h)': 'Stride length (m)',
#  'Date': 'HR (bpm)',
#  'Duration': 'Pace (min/km)',
#  'Max pace (min/km)': 'Power (W)',
#  'Max speed (km/h)': 'Distances (m)',
#  'Name': 'Sample rate',
#  'Sport': 'Time',
#  'Start time': 'Speed (km/h)',
#  'Total distance (km)': 'Cadence'}
#   Sample rate      Time HR (bpm) Speed (km/h) Pace (min/km) Cadence  \
# 2           1  00:00:00       87          0.0         00:00     NaN
# 3         NaN  00:00:01       87          0.0         00:00     NaN
# 4         NaN  00:00:02       87          0.0         00:00     NaN
# 5         NaN  00:00:03       87          0.0         00:00     NaN
# 6         NaN  00:00:04       87          3.7         16:10     NaN
#
#   Altitude (m) Stride length (m) Distances (m) Temperatures (C) Power (W)
# ...

# %% [markdown]
# #### Inspect:
# Time col is in hh:mm:ss format starting from 00:00:00. The rest of the files (coordinates and ts) are both using actual datetime. This field needs to be converted (added to the starting time)

# %%
start_time = pd.to_datetime(training_meta.loc["Date", :] + " " + training_meta.loc["Start time", :])
start_time = start_time[0]
print("start time: " + str(start_time))
training_ts["Time"] = pd.to_datetime(training_ts["Time"])
training_ts["h"] = pd.to_timedelta(training_ts["Time"].dt.hour, unit='h')
training_ts["m"] = pd.to_timedelta(training_ts["Time"].dt.minute, unit='m')
training_ts["s"] = pd.to_timedelta(training_ts["Time"].dt.second, unit='s')

training_ts["time_updated"] = start_time + training_ts["h"] + training_ts["m"] + training_ts["s"]
training_ts.drop(columns=["h", "m", "s"], inplace=True)

training_ts.set_index("time_updated", inplace=True)
# Out:
# start time: 2021-06-25 04:37:58

# %% [markdown]
# #### Inspect:
# time_updated (index) now containse the actual time of the day

# %%
print("head")
display(training_ts.head(3))
print("tail")
display(training_ts.tail(3))
# Out:
# head
#                     Sample rate                Time HR (bpm) Speed (km/h)  \
# time_updated
# 2021-06-25 04:37:58           1 2021-07-24 00:00:00       87          0.0
# 2021-06-25 04:37:59         NaN 2021-07-24 00:00:01       87          0.0
# 2021-06-25 04:38:00         NaN 2021-07-24 00:00:02       87          0.0
#
#                     Pace (min/km) Cadence Altitude (m) Stride length (m)  \
# time_updated
# 2021-06-25 04:37:58         00:00     NaN          116               NaN
# 2021-06-25 04:37:59         00:00     NaN          116               NaN
# 2021-06-25 04:38:00         00:00     NaN          116               NaN
#
#                     Distances (m) Temperatures (C) Power (W)
# time_updated
# 2021-06-25 04:37:58          0.00             26.9       NaN
# 2021-06-25 04:37:59          0.00             26.9       NaN
# 2021-06-25 04:38:00          0.00             26.9       NaN
# tail
# ...

# %%
try:
    df_list.remove(training_raw)
except:
    pass
df_list = df_list + [training_meta, training_ts]

df_names.remove("training_raw")
df_names = df_names + ['training_meta', 'training_ts']
df_names
# Out:
# ['coordinates', 'training_meta', 'training_ts']

# %% [markdown]
# #### Inspect
# - coordinates (gpx)

# %%
display(coordinates.shape)
display(coordinates.head())
display(coordinates.index[:5])
# Out:
# (34349, 3)
#                                    latitude  longitude  elevation
# time
# 2021-06-25 02:37:59.188000+00:00  46.754178  17.570482       90.0
# 2021-06-25 02:38:00.188000+00:00  46.754178  17.570482       90.0
# 2021-06-25 02:38:01.188000+00:00  46.754175  17.570480       90.0
# 2021-06-25 02:38:02.188000+00:00  46.754157  17.570477       90.0
# 2021-06-25 02:38:03.188000+00:00  46.754137  17.570477       91.0
# DatetimeIndex(['2021-06-25 02:37:59.188000+00:00',
#                '2021-06-25 02:38:00.188000+00:00',
#                '2021-06-25 02:38:01.188000+00:00',
#                '2021-06-25 02:38:02.188000+00:00',
#                '2021-06-25 02:38:03.188000+00:00'],
#               dtype='datetime64[ns, SimpleTZ("Z")]', name='time', freq=None)

# %%
coordinates['dttm'] = coordinates.index.astype(str).str[:19]
coordinates['dttm'] = pd.to_datetime(coordinates['dttm'])
coordinates.set_index('dttm', inplace=True)

display(coordinates.head())
coordinates.index = coordinates.index + pd.DateOffset(hours=2)

print("Offsetting the time by 2 hours:")
#coordinates['dttm'] = coordinates['dttm'] + pd.DateOffset(hours=2)
display(coordinates.head())
# Out:
#                       latitude  longitude  elevation
# dttm
# 2021-06-25 02:37:59  46.754178  17.570482       90.0
# 2021-06-25 02:38:00  46.754178  17.570482       90.0
# 2021-06-25 02:38:01  46.754175  17.570480       90.0
# 2021-06-25 02:38:02  46.754157  17.570477       90.0
# 2021-06-25 02:38:03  46.754137  17.570477       91.0
# Offsetting the time by 2 hours:
#                       latitude  longitude  elevation
# dttm
# 2021-06-25 04:37:59  46.754178  17.570482       90.0
# 2021-06-25 04:38:00  46.754178  17.570482       90.0
# 2021-06-25 04:38:01  46.754175  17.570480       90.0
# 2021-06-25 04:38:02  46.754157  17.570477       90.0
# 2021-06-25 04:38:03  46.754137  17.570477       91.0

# %% [markdown]
# #### File size reduction:
# Testing the tradeoff between the gpx file size reduction and plot accuracy by only keeping every nth row

# %%
# this function only keeps every nth row. (n=2 would cut the dataset in half)
def keep_every_nth_row(df, n):
    return df.iloc[::n, :]

# %%
dim_y = 5
dim_x = 5
n = 25
original_number_of_rows = str(coordinates.shape[0])

print("Original dataset size: " + original_number_of_rows)
print()
fig, ax = plt.subplots(dim_y, dim_x, figsize=(20,20))
for i in range(dim_y):
    for j in range(dim_x):
        coordinates_smaller = keep_every_nth_row(coordinates, n)
        ax[i, j].plot(coordinates_smaller['longitude'], coordinates_smaller['latitude'])
        title = "n:" +str(n) + "# of rows:" + str(coordinates_smaller.shape[0])
        ax[i, j].title.set_text(title)
        
        n = n + 25
# Out:
# Original dataset size: 34349

# %%
# insane file size reduction
x = keep_every_nth_row(coordinates, 2500)
plt.plot(x['longitude'], x['latitude'])
print(x.shape)
# Out:
# (14, 3)

# %%
import gmplot

# %%
my_gmap_api_key = ''
# starting view (lat, lon, zooom level)
gMapLayer = gmplot.GoogleMapPlotter(46.8571941,17.7682393,10, apikey=my_gmap_api_key)

# %%
# plot the route
#gMapLayer.scatter(coordinates.latitude, coordinates.longitude, color='red', size=60, marker=False)
gMapLayer.plot(coordinates.latitude, coordinates.longitude, color='c', edge_width=2.5)

# generate the html file
html_file = "gMap_route_dev.html"
gMapLayer.draw(html_file)

# embed the html file  Jupyter
from IPython.display import IFrame
IFrame(src=html_file, width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="gMap_route_dev.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### Merging training data with gps data

# %%
df_names = ["training_ts", "coordinates"]
df_list = [training_ts, coordinates]
df_zipped = zip(df_names, df_list)

for name, df in df_zipped:
    print("df name: " + name)
    display(df.head(8))
    
#clean df variable from memory
df = '_'
# Out:
# df name: training_ts
#                     Sample rate                Time HR (bpm) Speed (km/h)  \
# time_updated
# 2021-06-25 04:37:58           1 2021-07-24 00:00:00       87          0.0
# 2021-06-25 04:37:59         NaN 2021-07-24 00:00:01       87          0.0
# 2021-06-25 04:38:00         NaN 2021-07-24 00:00:02       87          0.0
# 2021-06-25 04:38:01         NaN 2021-07-24 00:00:03       87          0.0
# 2021-06-25 04:38:02         NaN 2021-07-24 00:00:04       87          3.7
# 2021-06-25 04:38:03         NaN 2021-07-24 00:00:05       86          5.6
# 2021-06-25 04:38:04         NaN 2021-07-24 00:00:06       86          7.0
# 2021-06-25 04:38:05         NaN 2021-07-24 00:00:07       85          8.5
#
#                     Pace (min/km) Cadence Altitude (m) Stride length (m)  \
# time_updated
# 2021-06-25 04:37:58         00:00     NaN          116               NaN
# 2021-06-25 04:37:59         00:00     NaN          116               NaN
# ...

# %%
df_zipped = zip(df_names, df_list)

for name, df in df_zipped:
    print("df name: " + name)
    display(df.shape)
    
#clean df variable from memory
df = '_'
# Out:
# df name: training_ts
# (34426, 11)
# df name: coordinates
# (34349, 3)

# %%
training_ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 34426 entries, 2021-06-25 04:37:58 to 2021-06-25 14:11:43
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sample rate        1 non-null      object
#  1   Time               34426 non-null  datetime64[ns]
#  2   HR (bpm)           34414 non-null  object
#  3   Speed (km/h)       34425 non-null  object
#  4   Pace (min/km)      34425 non-null  object
#  5   Cadence            34319 non-null  object
#  6   Altitude (m)       34426 non-null  object
#  7   Stride length (m)  0 non-null      object
#  8   Distances (m)      34426 non-null  object
#  9   Temperatures (C)   34426 non-null  object
#  10  Power (W)          0 non-null      object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 3.2+ MB

# %%
training_meta
# Out:
#                                                                                0
# Name                                                                Andrew Szabo
# Sport                                                                    CYCLING
# Date                                                                  2021.06.25
# Start time                                                           04:37:58 AM
# Duration                                                                09:33:46
# Total distance (km)                                                       207.37
# Average heart rate (bpm)                                                     114
# Average speed (km/h)                                                        21.7
# Max speed (km/h)                                                            52.0
# Average pace (min/km)                                                      02:46
# Max pace (min/km)                                                          01:09
# ...

# %%
start_time = pd.to_datetime(training_meta["Date"] + " " + training_meta["Start time"])
start_time
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-190215b19760> in <module>
# ----> 1 start_time = pd.to_datetime(training_meta["Date"] + " " + training_meta["Start time"])
# ...

# %%
x = training_ts.iloc[:,0:6]
x.head()

# %%
x["start_time"] = start_time
x.head()
